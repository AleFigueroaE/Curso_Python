# %%
import matplotlib.pyplot as plt

ventas = [20, 50, 30]
meses = ['Enero', 'Febrero', 'Marzo']

plt.pie(ventas, labels=meses, autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff','#99ff99'])

plt.show()

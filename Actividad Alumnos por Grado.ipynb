# %%
import matplotlib.pyplot as plt

grados = ["Primero", "Segundo", "Tercero", "Cuarto"]
alumnos = [20, 25, 29, 30]

plt.bar(grados, alumnos)

plt.title("Alumnos por grado")
plt.xlabel("Grado")
plt.ylabel("Número de alumnos")

# Mostrar la gráfica
plt.show()

# %% [markdown]
# Crea una gráfica que describa cuántos alumnos hay por cada grado. La gráfica debe ser clara y fácil de interpretar para el usuario.

# %%
import pandas as pd
import numpy as np
import altair as alt

data = pd.read_csv('cleanstudentscomplete.csv')
data.head()
# Out:
#    Unnamed: 0  Student ID     student_name       gender grade school_name  \
# 0           0           0     Paul Bradley  HoHombrebre   9th    Huang HS
# 1           1           1     Victor Smith       Hombre  12th    Huang HS
# 2           2           2  Kevin Rodriguez       Hombre  12th    Huang HS
# 3           3           3    Richard Scott       Hombre  12th    Huang HS
# 4           4           4       Bonnie Ray        Mujer   9th    Huang HS
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
grado_count = data['grade'].value_counts().to_frame().reset_index().rename(columns={'index':'grade','grade':'count'}) #Agrupo por grado y hago conteo
grado_count['percent'] = (grado_count['count'] / grado_count['count'].sum()) #Saco el promedio
grado_count
# Out:
#   grade  count   percent
# 0   9th  11408  0.291243
# 1  10th  10168  0.259586
# 2  11th   9695  0.247511
# 3  12th   7899  0.201659

# %%
bars= alt.Chart(grado_count).mark_bar(stroke = "white").encode(
    x= alt.X("percent:Q", 
        title = "", 
        axis = alt.Axis(format='.0%', grid = False, )),
    y= alt.Y("grade:O", 
        title="",
        axis = alt.Axis(labelAngle=0, labelFontSize=14, labelColor= "#343a40", labelFont="Arial") ),    
    tooltip = [alt.Tooltip('count', title = 'Count' ), alt.Tooltip ('grade:O',title = 'Grade' ) , alt.Tooltip('percent:Q', format='.1%', title = 'Percent' )],
    color=alt.Color(field="grade", type="nominal",legend=None ))

text = bars.mark_text(
    dx=+20,
    size=16,
    fill = "black",
).encode(text= alt.Text('percent:Q', format='.0%'))

(bars + text).properties(
    title = f"Alumnos por Grado",
    width = 600,
    height= 150,
).configure_title(
    fontSize = 20,
    font = "Arial",
).configure_view(
    strokeWidth = 0,)
# Out:
# alt.LayerChart(...)
